# %%
# read table data
from pygmid import Lookup as lk
import numpy as np
lv_nmos = lk('sg13_lv_nmos.mat')
lv_pmos = lk('sg13_lv_pmos.mat')
# list of parameters: VGS, VDS, VSB, L, W, NFING, ID, VT, GM, GMB, GDS, CGG, CGB, CGD, CGS, CDD, CSS, STH, SFL
# if not specified, minimum L, VDS=max(vgs)/2=0.9 and VSB=0 are used

# %%
gm_id_m15_16_11 = lv_nmos.lookup('GM_ID', ID_W=3.5e-06, L=2)
gm_id_m13 = lv_nmos.lookup('GM_ID', ID_W=3.5e-06, L=2, VDS=0.2)
gm_id_m12 = lv_nmos.lookup('GM_ID', ID_W=7e-06, L=2)
gm_id_m14 = lv_nmos.lookup('GM_ID', ID_W=0.93e-06, L=0.5, VDS=0.2)

gm_id_mtb = lv_pmos.lookup('GM_ID', ID_W=0.5e-06, L=5)
gm_id_m10 = lv_pmos.lookup('GM_ID', ID_W=0.87e-06, L=2)

print (gm_id_m15_16_11)
print (gm_id_m13)
print (gm_id_m10)
print (gm_id_mtb)
print (gm_id_m12)
print (gm_id_m14)
# Out:
# 10.616327275541444
# 10.341439629435119
# 10.934938050609198
# 7.690021426904883
# 8.050870374459608
# 21.39412946177391
