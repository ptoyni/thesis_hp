# %%
# read table data
from pygmid import Lookup as lk
import numpy as np
lv_nmos = lk('sg13_lv_nmos.mat')
lv_pmos = lk('sg13_lv_pmos.mat')
# list of parameters: VGS, VDS, VSB, L, W, NFING, ID, VT, GM, GMB, GDS, CGG, CGB, CGD, CGS, CDD, CSS, STH, SFL
# if not specified, minimum L, VDS=max(vgs)/2=0.9 and VSB=0 are used

# %%
gm_id_m13_11_12_17 = lv_pmos.lookup('GM_ID', ID_W=0.89e-06, L=2, VDS=0.2)
gm_id_m18 = lv_pmos.lookup('GM_ID', ID_W=0.89e-06, L=0.5, VDS=0.2)
gm_id_m14_15_16 = lv_nmos.lookup('GM_ID', ID_W=4.16e-06, L=2, VDS=0.2)
gm_id_m10 = lv_nmos.lookup('GM_ID', ID_W=0.83e-06, L=0.5, VDS=0.2)

print (gm_id_m13_11_12_17)
print (gm_id_m18)
print (gm_id_m10)
print (gm_id_m14_15_16)
# Out:
# 10.391074902316163
# 14.624062652734453
# 21.966504725839876
# 9.58596127150922
